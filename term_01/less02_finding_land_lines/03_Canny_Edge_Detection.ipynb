# %% [markdown]
# # Canny Edge Detection in Action

# %% [markdown]
# ## Import dependencies

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimage
import numpy as np
import cv2

# %matplotlib inline

def imshow(img,cmap = 'gray'):
    plt.figure()
    plt.imshow(img,cmap=cmap)

# %% [markdown]
# ## Load data

# %%
img = mpimage.imread('exit-ramp.jpg')
imshow(img)

# %% [markdown]
# ## Prepocessing

# %%
#convert to gray image
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
imshow(gray)

#Gaussian blur
kernel_size = 3
smooth_gray = cv2.GaussianBlur(gray,(kernel_size,kernel_size),0)

# %%
## Canny edge detector
low_threshold = 75
high_threshold = 100
edges = cv2.Canny(smooth_gray,low_threshold,high_threshold)
plt.figure()
plt.imshow(edges,cmap='gray')

# %%
cv2.Canny?
